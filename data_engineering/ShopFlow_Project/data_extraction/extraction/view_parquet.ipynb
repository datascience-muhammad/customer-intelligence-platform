# %%
import pandas as pd
from pathlib import Path

# %%
# Set the parquet file path here
file_path = r"C:\Users\David Ibanga\Data Engineering practicals\ShopFlow_Project\data_extraction\local_output\curated\dim_customers\extract_date=2025-12-22\dim_customers_20251222T215118Z.parquet"

# Or use absolute path:
# file_path = r"C:\Users\David Ibanga\Data Engineering practicals\ShopFlow_Project\data_extraction\local_output\raw\customers.parquet"

# %%
# Read parquet file
df = pd.read_parquet(file_path)

print(f"Total rows: {len(df):,}")
print(f"Total columns: {len(df.columns)}")
print(f"\nColumns: {list(df.columns)}")
# Out:
# Total rows: 100,000
# Total columns: 15
#
# Columns: ['customer_id', 'email', 'name', 'city', 'country', 'signup_date', 'customer_segment', 'total_orders', 'total_spent', 'tenure_days', 'total_support_tickets', 'avg_satisfaction_score', 'avg_resolution_hours', 'open_tickets_count', 'last_ticket_date']

# %%
# Display first 20 rows
df.head(20)
# Out:
#    customer_id                    email              name                city  \
# 0   CUST000001  cust000001@shopflow.com        Adam Allen           Marshfurt
# 1   CUST000005  cust000005@shopflow.com     James Elliott           New Tonya
# 2   CUST000006  cust000006@shopflow.com   Alexander Jones         West Thomas
# 3   CUST000007  cust000007@shopflow.com   Patricia Thomas       West Dawnberg
# 4   CUST000008  cust000008@shopflow.com   Hayley Martinez           Wattsview
# 5   CUST000010  cust000010@shopflow.com     Brian Barajas          Port Paula
# 6   CUST000012  cust000012@shopflow.com   Theresa Ramirez     North Alexander
# 7   CUST000014  cust000014@shopflow.com     Jasmine Johns         Webbchester
# 8   CUST000015  cust000015@shopflow.com        Gina Smith   Port Courtneyberg
# 9   CUST000016  cust000016@shopflow.com      Mathew Brady           Amandaton
# 10  CUST000019  cust000019@shopflow.com   Miranda Ramirez        North Kendra
# ...

# %%
# Show data types and null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   customer_id             100000 non-null  object
#  1   email                   100000 non-null  object
#  2   name                    100000 non-null  object
#  3   city                    100000 non-null  object
#  4   country                 100000 non-null  object
#  5   signup_date             100000 non-null  datetime64[ns]
#  6   customer_segment        100000 non-null  object
#  7   total_orders            100000 non-null  int64
#  8   total_spent             100000 non-null  float64
#  9   tenure_days             100000 non-null  int64
#  10  total_support_tickets   100000 non-null  int64
#  11  avg_satisfaction_score  100000 non-null  float64
#  12  avg_resolution_hours    100000 non-null  int64
#  13  open_tickets_count      100000 non-null  int64
# ...

# %%
# Show basic statistics for numeric columns
df.describe()
# Out:
#                       signup_date   total_orders    total_spent  \
# count                      100000  100000.000000  100000.000000
# mean   2023-06-16 15:55:53.184000       5.000000    3818.304709
# min           2022-01-01 00:00:00       0.000000       0.000000
# 25%           2022-09-22 00:00:00       3.000000    1893.080000
# 50%           2023-06-17 00:00:00       5.000000    3513.010000
# 75%           2024-03-08 00:00:00       7.000000    5377.785000
# max           2024-11-29 00:00:00      20.000000   20204.480000
# std                           NaN       2.845646    2544.208797
#
#          tenure_days  total_support_tickets  avg_satisfaction_score  \
# count  100000.000000          100000.000000           100000.000000
# mean      919.336190               0.500000                1.041144
# min       388.000000               0.000000                0.000000
# 25%       654.000000               0.000000                0.000000
# ...
